# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindmurali93/ICTAC-assignment-/blob/main/Aravind_M_assignment_on_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("/content/Students_Performance (1).csv")

# %%
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
data1.shape
# Out:
# (1000, 8)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data1.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data1.mean()
# Out:
# <ipython-input-10-3ea1a6dabdbd>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1.mean()
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %% [markdown]
# **The number of males and females participated in the test**

# %%
data1['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# **Parental level of education**

# %%
data1['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# **scoring average**

# %%
data1['total'] = data1['math score'] + data1['reading score'] + data1['writing score']

# %%
data1['average'] =data1['total']/3

# %%
data1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %% [markdown]
# **based on gender**

# %%
sns.countplot(x= "average", hue="gender",data=data1)
# Out:
# <Axes: xlabel='average', ylabel='count'>

# %% [markdown]
# **based on test preparation course**

# %%
sns.countplot(x= "average", hue="test preparation course",data=data1)
# Out:
# <Axes: xlabel='average', ylabel='count'>

# %% [markdown]
# male and female students are performin equally for maths and all other subjects

# %% [markdown]
# **Giving Bounus points to students having 75% and above**

# %%
def Grade(average):
  if (average >= 75): return 'yes'
  else :return 'no'

# %%
data1["bonus points"] = data1.apply(lambda x :Grade(x['average']),axis=1)

# %%
data1.head(1000)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
df = pd.read_csv('/content/Sales_add (1).csv')

# %%
df.head()
# Out:
#      Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0  Month-1  Region - A  Manager - A                          132921
# 1  Month-2  Region - A  Manager - C                          149559
# 2  Month-3  Region - B  Manager - A                          146278
# 3  Month-4  Region - B  Manager - B                          152167
# 4  Month-5  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Month                           22 non-null     object
#  1   Region                          22 non-null     object
#  2   Manager                         22 non-null     object
#  3   Sales_before_digital_add(in $)  22 non-null     int64
#  4   Sales_After_digital_add(in $)   22 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1008.0+ bytes

# %%
df.shape
# Out:
# (22, 5)

# %%
df.isna().sum()
# Out:
# Month                             0
# Region                            0
# Manager                           0
# Sales_before_digital_add(in $)    0
# Sales_After_digital_add(in $)     0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-82-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Sales_before_digital_add(in $)    149239.954545
# Sales_After_digital_add(in $)     231123.727273
# dtype: float64

# %%
df.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
import statistics as stat

# %%
from statsmodels.stats.weightstats import ztest

# %%
z_stat3,pvalue3 = ztest( df['Sales_After_digital_add(in $)'])

# %%
pvalue3
# Out:
# 1.3046367348248653e-38

# %%
if pvalue3<0.05 :
  print('Reject null hypothesis')
else :
    print ('accept null hypothesis')
# Out:
# Reject null hypothesis
